# %% [markdown]
# # Exploración inicial del dataset de Puntos de Interés (POI)
#
# En este Notebook haremos la **EDA** (*Exploratory Data Analysis*) para:
#
# ### Objetivos de esta EDA
#
# 1. **Comprender el tamaño y la estructura** del dataset (nº de filas, columnas y su tipado).
# 2. **Evaluar la calidad de los datos**
#    * Detectar valores nulos, duplicados o incoherentes.
#    * Verificar rangos y distribuciones para cada variable.
# 3. **Identificar posibles problemas** que resolveremos durante el preprocesado:
#    * Columnas irrelevantes, codificación de categorías de alta cardinalidad, métricas de engagement sesgadas, etc.
# 4. **Visión rápida del target**: inspeccionar la futura métrica de engagement para asegurarnos de que no hay clases muy desbalanceadas.

# %% [markdown]
# Importamos Librerias a usar en este NoteBook:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import cv2

# %% [markdown]
# Cargamos y Visualizamos nuestro dataset:

# %%
data = pd.read_csv('poi_dataset.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1569 entries, 0 to 1568
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1569 non-null   object
#  1   name              1569 non-null   object
#  2   shortDescription  1569 non-null   object
#  3   categories        1569 non-null   object
#  4   tier              1569 non-null   int64
#  5   locationLon       1569 non-null   float64
#  6   locationLat       1569 non-null   float64
#  7   tags              1569 non-null   object
#  8   xps               1569 non-null   int64
#  9   Visits            1569 non-null   int64
#  10  Likes             1569 non-null   int64
#  11  Dislikes          1569 non-null   int64
#  12  Bookmarks         1569 non-null   int64
#  13  main_image_path   1569 non-null   object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 171.7+ KB

# %% [markdown]
# ## Metadatos del dataset
#
# | Columna | Tipo (`dtype`) | Descripción breve |
# |---------|---------------|-------------------|
# | `id` | object | Identificador único del POI |
# | `name` | object | Nombre del POI |
# | `shortDescription` | object | Descripción textual corta |
# | `categories` | object | Lista de categorías principales |
# | `tags` | object | Lista amplia de etiquetas descriptivas |
# | `tier` | int64 | Nivel de relevancia |
# | `locationLon` | float64 | Longitud geográfica |
# | `locationLat` | float64 | Latitud geográfica |
# | `xps` | int64 | Puntuación de experiencia para el usuario |
# | `Visits` | int64 | Nº de Visitas |
# | `Likes` | int64 | Nº de “me gusta” |
# | `Dislikes` | int64 | Nº de “no me gusta” |
# | `Bookmarks` | int64 | Nº de marcadores |
# | `main_image_path` | object | Ruta local a la imagen principal |
#
# ### Fotografía global del dataset
#
# * **Filas:** 1 569
# * **Columnas:** 14
# * **Valores nulos:** 0
# * **Tipos numéricos:** 2 floats + 6 ints
# * **Columnas `object` a transformar:** `id`, `name`, `shortDescription`, `categories`, `tags`, `main_image_path`

# %%
data.head()
# Out:
#                                      id  \
# 0  4b36a3ed-3b28-4bc7-b975-1d48b586db03
# 1  e32b3603-a94f-49df-8b31-92445a86377c
# 2  0123a69b-13ac-4b65-a5d5-71a95560cff5
# 3  390d7d9e-e972-451c-b5e4-f494af15e788
# 4  023fc1bf-a1cd-4b9f-af78-48792ab1a294
#
#                                                 name  \
# 0                                  Galería Fran Reus
# 1                            Convento de San Plácido
# 2             Instituto Geológico y Minero de España
# 3                              Margarita Gil Roësset
# 4  Museo del Traje. Centro de Investigación del P...
#
#                                     shortDescription  \
# 0  La Galería Fran Reus es un espacio dedicado a ...
# 1  El Convento de San Plácido en Madrid, fundado ...
# 2  El Instituto Geológico y Minero de España, sit...
# 3  Margarita Gil Roësset, escultora y poetisa esp...
# 4  El Museo del Traje de Madrid, fundado en 2004,...
#
#                    categories  tier  locationLon  locationLat tags  xps  \
# 0    ['Escultura', 'Pintura']     1     2.642262    39.572694   []  500
# 1  ['Patrimonio', 'Historia']     1    -3.704467    40.423037   []  500
# 2   ['Ciencia', 'Patrimonio']     2    -3.699694    40.442045   []  250
# 3                 ['Cultura']     1    -3.691228    40.427256   []  500
# 4   ['Patrimonio', 'Cultura']     1    -3.727822    40.439665   []  500
#
#    Visits  Likes  Dislikes  Bookmarks  \
# 0   10009    422      3582         78
# 1   10010   7743        96       2786
# 2   10015   3154       874        595
# 3   10011   8559        79       2358
# 4   10020    915      2896        143
#
#                                      main_image_path
# 0  data_main/4b36a3ed-3b28-4bc7-b975-1d48b586db03...
# 1  data_main/e32b3603-a94f-49df-8b31-92445a86377c...
# 2  data_main/0123a69b-13ac-4b65-a5d5-71a95560cff5...
# 3  data_main/390d7d9e-e972-451c-b5e4-f494af15e788...
# 4  data_main/023fc1bf-a1cd-4b9f-af78-48792ab1a294...

# %% [markdown]
# ### Inspección rápida de tags

# %%
print(data["tags"].str.contains("\[\]").sum())
print(data["tags"].str.strip()=="[]")
print("Porcentaje de POIs con tags []: ", data["tags"].str.strip().value_counts(normalize=True)["[]"] * 100)
# Out:
# 107
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1564    False
# 1565    False
# 1566    False
# 1567    False
# 1568    False
# Name: tags, Length: 1569, dtype: bool
# Porcentaje de POIs con tags []:  6.8196303377947745

# %% [markdown]
# > **Hallazgo sobre `tags`**
# > * Registros sin etiquetas: **107** de **1 569** (≈ 6,8 %).

# %% [markdown]
# ### Estadísticos descriptivos

# %%
data.describe()
# Out:
#               tier  locationLon  locationLat          xps        Visits  \
# count  1569.000000  1569.000000  1569.000000  1569.000000   1569.000000
# mean      1.541109    -1.132337    39.900141   750.382409  10011.943276
# std       0.637677    22.733401     9.662134   228.319854      5.456808
# min       1.000000  -121.951049   -62.940930     0.000000  10001.000000
# 25%       1.000000    -3.725292    40.411754   600.000000  10008.000000
# 50%       1.000000    -3.699140    40.421738   700.000000  10011.000000
# 75%       2.000000    -3.673348    40.472458  1000.000000  10015.000000
# max       4.000000   158.333118    65.706572  1000.000000  10038.000000
#
#               Likes      Dislikes    Bookmarks
# count   1569.000000   1569.000000  1569.000000
# mean    3623.908222   2526.305927   973.261950
# std     4817.879374   2225.543360  1453.333948
# min      100.000000     52.000000    50.000000
# 25%      464.000000    937.000000   116.000000
# 50%     1434.000000   2718.000000   306.000000
# 75%     6840.000000   3399.000000  1309.000000
# max    26425.000000  10999.000000  8157.000000

# %% [markdown]
# * **Métricas de engagement muy sesgadas** (`Visits`, `Likes`, `Dislikes`, `Bookmarks`)
#   * Máximos muy superiores a la media → distribuciones con colas pronunciadas.
#   * Evaluaremos transformar con `log1p`

# %%
#Exploramos nuestro campo 'xps'
print(data['xps'].describe())
data['xps'].hist(bins=50)
plt.title('Histograma de XPS')
# Out:
# count    1569.000000
# mean      750.382409
# std       228.319854
# min         0.000000
# 25%       600.000000
# 50%       700.000000
# 75%      1000.000000
# max      1000.000000
# Name: xps, dtype: float64
# Text(0.5, 1.0, 'Histograma de XPS')

# %% [markdown]
# #### Hallazgos sobre `xps`
#
# * **Escala discreta** → los valores aparecen en saltos de 100 pts (0, 100, 200, …, 1000).
# * **Sesgo a la derecha** → el pico principal está en 1000 pts.
#
#
# > Esto sugiere que `xps` podría ser una **puntuación de “nivel”** o “gamificación” ya normalizada.
# > En el modelado lo trataremos como **numérica discreta** (o incluso *ordinal*), y seguramente no necesitaremos normalizarla salvo para escalar todas las features al mismo rango.

# %%
#Exploramos el campo 'tier'
print(data['tier'].describe())
data['tier'].hist(bins=50)
plt.title('Histograma de TIER')
# Out:
# count    1569.000000
# mean        1.541109
# std         0.637677
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: tier, dtype: float64
# Text(0.5, 1.0, 'Histograma de TIER')

# %% [markdown]
# #### Hallazgos sobre `tier`
#
# * Variable **ordinal** con 4 niveles (1 → mínima relevancia, 4 → máxima).
# * Distribución desequilibrada

# %%
num_cols = ['tier', 'xps', 'Likes', 'Dislikes', 'Bookmarks', 'Visits']
corr = data[num_cols].corr(method='pearson')

plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Matriz de correlación (Pearson)"); plt.tight_layout()
plt.show()


sns.boxplot(x='tier', y='xps', data=data)
plt.title("Tier y XPS"); plt.show()

# %% [markdown]
# #### Matriz de correlación
#
# * **Multicolinealidad**
#   * `Likes` y `Bookmarks` presentan ρ = 0.97 → una de las dos puede eliminarse o combinarse (`engagement_score = Likes + Bookmarks`).
# * **Polaridad de la opinión**
#   * `Likes` y `Dislikes` correlan -0.54 → confirman que representan extremos opuestos de una misma métrica.
# * **Relación inversa `tier` vs `xps`**
#   * ρ = -0.76 sugiere que los POIs más relevantes (Tier alto) requieren menor “experiencia” (`xps`) para el usuario, o que ambos se calculan con criterios diferentes.
# * **`Visits` casi desligado** del resto → podría aportar señal complementaria.
#
# > **Implicaciones**
# > * Revisar multicolinealidad antes de entrenar modelos lineales.
# > * Evaluar fusión/eliminación de `Likes` & `Bookmarks`.
# > * Profundizar en la definición de `tier` y `xps` para entender su relación.

# %% [markdown]
# ## Columnas tipo *object*
# ### Detección de duplicados
# Comprobamos si el identificador `id`que **debería ser único** para cada POI
# aparece repetido.

# %%
dup_rows   = data['id'].duplicated().sum()         # 77 filas duplicadas
dup_pois   = data[data['id'].duplicated(keep=False)]['id'].nunique()  #  nº POIs afectados
pct_rows   = dup_rows / len(data) * 100
print(f"Filas duplicadas: {dup_rows}  ({pct_rows:.1f} %)")
# Out:
# Filas duplicadas: 77  (4.9 %)

# %%
# Revisamos si con esas ids hay duplicados en las demás columnas
for id in duplicate_ids:
    duplicate_rows = data[data['id'] == id]
    if duplicate_rows.shape[0] > 1:
        print(f"Duplicate rows for ID {id}:")
        print(duplicate_rows)
# Out:
# Duplicate rows for ID 04be145b-f73e-41aa-9332-d1702684dc53:
#                                         id                   name  \
# 1178  04be145b-f73e-41aa-9332-d1702684dc53  El bosque de Dartmoor
# 1179  04be145b-f73e-41aa-9332-d1702684dc53  El bosque de Dartmoor
# 1180  04be145b-f73e-41aa-9332-d1702684dc53  El bosque de Dartmoor
# 1181  04be145b-f73e-41aa-9332-d1702684dc53  El bosque de Dartmoor
#
#                                        shortDescription  \
# 1178  Explora Dartmoor, el misterioso páramo que ins...
# 1179  Explora Dartmoor, el misterioso páramo que ins...
# 1180  Explora Dartmoor, el misterioso páramo que ins...
# 1181  Explora Dartmoor, el misterioso páramo que ins...
#
#                                        categories  tier  locationLon  \
# 1178  ['Ocio', 'Historia', 'Cultura', 'Misterio']     1    -3.901605
# 1179  ['Ocio', 'Historia', 'Cultura', 'Misterio']     1    -3.901605
# 1180  ['Ocio', 'Historia', 'Cultura', 'Misterio']     1    -3.901605
# 1181  ['Ocio', 'Historia', 'Cultura', 'Misterio']     1    -3.901605
#
#       locationLat                 tags   xps  Visits  Likes  Dislikes  \
# 1178    50.580627  ['Sherlock Holmes']  1000   10007   2676      1610
# 1179    50.580627            ['Perro']  1000   10003   2388      1017
# 1180    50.580627       ['Naturaleza']  1000   10006   2701      1018
# 1181    50.580627           ['Bestia']  1000   10008   2645      1287
#
#       Bookmarks                                    main_image_path
# 1178        611  data_main/04be145b-f73e-41aa-9332-d1702684dc53...
# 1179        619  data_main/04be145b-f73e-41aa-9332-d1702684dc53...
# 1180        594  data_main/04be145b-f73e-41aa-9332-d1702684dc53...
# 1181        775  data_main/04be145b-f73e-41aa-9332-d1702684dc53...
# Duplicate rows for ID 9d06c579-b645-41ce-b2f4-b57524cc7cea:
#                                         id                       name  \
# 1232  9d06c579-b645-41ce-b2f4-b57524cc7cea  El cementerio de Highgate
# 1233  9d06c579-b645-41ce-b2f4-b57524cc7cea  El cementerio de Highgate
# 1234  9d06c579-b645-41ce-b2f4-b57524cc7cea  El cementerio de Highgate
# 1235  9d06c579-b645-41ce-b2f4-b57524cc7cea  El cementerio de Highgate
# 1236  9d06c579-b645-41ce-b2f4-b57524cc7cea  El cementerio de Highgate
#
#                                        shortDescription  \
# 1232  Explora el místico cementerio de Highgate, don...
# 1233  Explora el místico cementerio de Highgate, don...
# 1234  Explora el místico cementerio de Highgate, don...
# 1235  Explora el místico cementerio de Highgate, don...
# 1236  Explora el místico cementerio de Highgate, don...
#
#                                        categories  tier  locationLon  \
# 1232  ['Cine', 'Cultura', 'Historia', 'Misterio']     1    -0.147064
# 1233  ['Cine', 'Cultura', 'Historia', 'Misterio']     1    -0.147064
# 1234  ['Cine', 'Cultura', 'Historia', 'Misterio']     1    -0.147064
# 1235  ['Cine', 'Cultura', 'Historia', 'Misterio']     1    -0.147064
# 1236  ['Cine', 'Cultura', 'Historia', 'Misterio']     1    -0.147064
#
#       locationLat                tags   xps  Visits  Likes  Dislikes  \
# 1232    51.566995      ['Victoriano']  1000   10010   8720        81
# 1233    51.566995          ['Terror']  1000   10018   2359      1088
# 1234    51.566995  ['Prerrafaelitas']  1000   10014    593      2650
# 1235    51.566995         ['Dickens']  1000   10005    918      2665
# 1236    51.566995     ['Cementerios']  1000   10015   8293       124
#
#       Bookmarks                                    main_image_path
# 1232       2587  data_main/9d06c579-b645-41ce-b2f4-b57524cc7cea...
# 1233        694  data_main/9d06c579-b645-41ce-b2f4-b57524cc7cea...
# 1234         93  data_main/9d06c579-b645-41ce-b2f4-b57524cc7cea...
# 1235        142  data_main/9d06c579-b645-41ce-b2f4-b57524cc7cea...
# 1236       2537  data_main/9d06c579-b645-41ce-b2f4-b57524cc7cea...
# Duplicate rows for ID 5b38dcaa-19ac-422d-9c74-5b29e2a19629:
#                                         id                               name  \
# 1244  5b38dcaa-19ac-422d-9c74-5b29e2a19629  La iglesia de los nueve fantasmas
# 1245  5b38dcaa-19ac-422d-9c74-5b29e2a19629  La iglesia de los nueve fantasmas
# 1246  5b38dcaa-19ac-422d-9c74-5b29e2a19629  La iglesia de los nueve fantasmas
# 1247  5b38dcaa-19ac-422d-9c74-5b29e2a19629  La iglesia de los nueve fantasmas
# 1248  5b38dcaa-19ac-422d-9c74-5b29e2a19629  La iglesia de los nueve fantasmas
# 1249  5b38dcaa-19ac-422d-9c74-5b29e2a19629  La iglesia de los nueve fantasmas
#
#                                        shortDescription  \
# 1244  Visita la iglesia de los nueve fantasmas en Lu...
# 1245  Visita la iglesia de los nueve fantasmas en Lu...
# 1246  Visita la iglesia de los nueve fantasmas en Lu...
# 1247  Visita la iglesia de los nueve fantasmas en Lu...
# 1248  Visita la iglesia de los nueve fantasmas en Lu...
# 1249  Visita la iglesia de los nueve fantasmas en Lu...
#
#                                categories  tier  locationLon  locationLat  \
# 1244  ['Cultura', 'Historia', 'Misterio']     1    13.160577    50.016484
# 1245  ['Cultura', 'Historia', 'Misterio']     1    13.160577    50.016484
# 1246  ['Cultura', 'Historia', 'Misterio']     1    13.160577    50.016484
# 1247  ['Cultura', 'Historia', 'Misterio']     1    13.160577    50.016484
# 1248  ['Cultura', 'Historia', 'Misterio']     1    13.160577    50.016484
# 1249  ['Cultura', 'Historia', 'Misterio']     1    13.160577    50.016484
#
#                   tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1244   ['Instalación']  1000   10011   3011       931        567
# 1245      ['Iglesias']  1000   10010    852      2714        101
# 1246     ['Fantasmas']  1000   10008    835      2792        179
# 1247  ['Curiosidades']  1000   10016    602      3215         74
# 1248          ['Arte']  1000   10015  24632       340       6742
# 1249   ['Abandonados']  1000   10012   8780        60       2620
#
#                                         main_image_path
# 1244  data_main/5b38dcaa-19ac-422d-9c74-5b29e2a19629...
# 1245  data_main/5b38dcaa-19ac-422d-9c74-5b29e2a19629...
# 1246  data_main/5b38dcaa-19ac-422d-9c74-5b29e2a19629...
# 1247  data_main/5b38dcaa-19ac-422d-9c74-5b29e2a19629...
# 1248  data_main/5b38dcaa-19ac-422d-9c74-5b29e2a19629...
# 1249  data_main/5b38dcaa-19ac-422d-9c74-5b29e2a19629...
# Duplicate rows for ID 8313dc99-1dd6-4994-976a-505650fb5c7e:
#                                         id                    name  \
# 1272  8313dc99-1dd6-4994-976a-505650fb5c7e  Las figuras de Okinawa
# 1273  8313dc99-1dd6-4994-976a-505650fb5c7e  Las figuras de Okinawa
# 1274  8313dc99-1dd6-4994-976a-505650fb5c7e  Las figuras de Okinawa
# 1275  8313dc99-1dd6-4994-976a-505650fb5c7e  Las figuras de Okinawa
# 1276  8313dc99-1dd6-4994-976a-505650fb5c7e  Las figuras de Okinawa
#
#                                        shortDescription  \
# 1272  ¡Descubre el misterio de Okinawa! Enigmas arqu...
# 1273  ¡Descubre el misterio de Okinawa! Enigmas arqu...
# 1274  ¡Descubre el misterio de Okinawa! Enigmas arqu...
# 1275  ¡Descubre el misterio de Okinawa! Enigmas arqu...
# 1276  ¡Descubre el misterio de Okinawa! Enigmas arqu...
#
#                                categories  tier  locationLon  locationLat  \
# 1272  ['Cultura', 'Historia', 'Misterio']     1   127.693849    26.227314
# 1273  ['Cultura', 'Historia', 'Misterio']     1   127.693849    26.227314
# 1274  ['Cultura', 'Historia', 'Misterio']     1   127.693849    26.227314
# 1275  ['Cultura', 'Historia', 'Misterio']     1   127.693849    26.227314
# 1276  ['Cultura', 'Historia', 'Misterio']     1   127.693849    26.227314
#
#                    tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1272      ['Pirámides']  1000   10007   8481        77       2501
# 1273        ['Piedras']  1000   10011   8527       109       2530
# 1274     ['Orientales']  1000   10017   2861      1100        416
# 1275         ['Museos']  1000   10009    626      2750        127
# 1276  ['Cultura Jomon']  1000   10028   8803        99       2559
#
#                                         main_image_path
# 1272  data_main/8313dc99-1dd6-4994-976a-505650fb5c7e...
# 1273  data_main/8313dc99-1dd6-4994-976a-505650fb5c7e...
# 1274  data_main/8313dc99-1dd6-4994-976a-505650fb5c7e...
# 1275  data_main/8313dc99-1dd6-4994-976a-505650fb5c7e...
# 1276  data_main/8313dc99-1dd6-4994-976a-505650fb5c7e...
# Duplicate rows for ID 8083365a-4ad8-45a2-b08a-e7ea63bf1db0:
#                                         id                name  \
# 1295  8083365a-4ad8-45a2-b08a-e7ea63bf1db0  Megalitos en Asuka
# 1296  8083365a-4ad8-45a2-b08a-e7ea63bf1db0  Megalitos en Asuka
# 1297  8083365a-4ad8-45a2-b08a-e7ea63bf1db0  Megalitos en Asuka
# 1298  8083365a-4ad8-45a2-b08a-e7ea63bf1db0  Megalitos en Asuka
#
#                                        shortDescription  \
# 1295  ¡Explora los misteriosos megalitos de Asuka! D...
# 1296  ¡Explora los misteriosos megalitos de Asuka! D...
# 1297  ¡Explora los misteriosos megalitos de Asuka! D...
# 1298  ¡Explora los misteriosos megalitos de Asuka! D...
#
#                                           categories  tier  locationLon  \
# 1295  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1   135.803626
# 1296  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1   135.803626
# 1297  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1   135.803626
# 1298  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1   135.803626
#
#       locationLat             tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1295    34.465609  ['Yacimientos']  1000   10008   1727      6467        299
# 1296    34.465609      ['Parques']  1000   10013    748      2789        116
# 1297    34.465609       ['Museos']  1000   10009   3282      1418        653
# 1298    34.465609    ['Megalitos']  1000   10013   2348      1528        447
#
#                                         main_image_path
# 1295  data_main/8083365a-4ad8-45a2-b08a-e7ea63bf1db0...
# 1296  data_main/8083365a-4ad8-45a2-b08a-e7ea63bf1db0...
# 1297  data_main/8083365a-4ad8-45a2-b08a-e7ea63bf1db0...
# 1298  data_main/8083365a-4ad8-45a2-b08a-e7ea63bf1db0...
# Duplicate rows for ID 23869080-e075-47f0-bb14-a07f6c704995:
#                                         id                     name  \
# 1299  23869080-e075-47f0-bb14-a07f6c704995  El castillo de Dunvegan
# 1300  23869080-e075-47f0-bb14-a07f6c704995  El castillo de Dunvegan
# 1301  23869080-e075-47f0-bb14-a07f6c704995  El castillo de Dunvegan
# 1302  23869080-e075-47f0-bb14-a07f6c704995  El castillo de Dunvegan
#
#                                        shortDescription  \
# 1299  ¡Visita el castillo de Dunvegan! Descubre 700 ...
# 1300  ¡Visita el castillo de Dunvegan! Descubre 700 ...
# 1301  ¡Visita el castillo de Dunvegan! Descubre 700 ...
# 1302  ¡Visita el castillo de Dunvegan! Descubre 700 ...
#
#                                              categories  tier  locationLon  \
# 1299  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    -6.590018
# 1300  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    -6.590018
# 1301  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    -6.590018
# 1302  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    -6.590018
#
#       locationLat           tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1299    57.448512    ['Leyenda']  1000   10018   3143      1225        515
# 1300    57.448512     ['Clanes']  1000   10007   2883      1323        439
# 1301    57.448512  ['Castillos']  1000   10006    926      2872        131
# 1302    57.448512    ['Bandera']  1000   10004   6952      3148       1505
#
#                                         main_image_path
# 1299  data_main/23869080-e075-47f0-bb14-a07f6c704995...
# 1300  data_main/23869080-e075-47f0-bb14-a07f6c704995...
# 1301  data_main/23869080-e075-47f0-bb14-a07f6c704995...
# 1302  data_main/23869080-e075-47f0-bb14-a07f6c704995...
# Duplicate rows for ID af0f8a7b-ca71-469e-a882-f20705acf206:
#                                         id                          name  \
# 1304  af0f8a7b-ca71-469e-a882-f20705acf206  El pueblo fantasma de Nagoro
# 1305  af0f8a7b-ca71-469e-a882-f20705acf206  El pueblo fantasma de Nagoro
# 1306  af0f8a7b-ca71-469e-a882-f20705acf206  El pueblo fantasma de Nagoro
# 1307  af0f8a7b-ca71-469e-a882-f20705acf206  El pueblo fantasma de Nagoro
#
#                                        shortDescription  \
# 1304  Visita Nagoro, el pueblo fantasma. Descubre 40...
# 1305  Visita Nagoro, el pueblo fantasma. Descubre 40...
# 1306  Visita Nagoro, el pueblo fantasma. Descubre 40...
# 1307  Visita Nagoro, el pueblo fantasma. Descubre 40...
#
#                                             categories  tier  locationLon  \
# 1304  ['Historia', 'Escultura', 'Cultura', 'Misterio']     1   134.018389
# 1305  ['Historia', 'Escultura', 'Cultura', 'Misterio']     1   134.018389
# 1306  ['Historia', 'Escultura', 'Cultura', 'Misterio']     1   134.018389
# 1307  ['Historia', 'Escultura', 'Cultura', 'Misterio']     1   134.018389
#
#       locationLat             tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1304    33.855356       ['Pueblo']  1000   10014    187      3334        147
# 1305    33.855356      ['Muñecos']  1000   10013    320      3572         53
# 1306    33.855356    ['Maniquíes']  1000   10014    222      3018         56
# 1307    33.855356  ['Abandonados']  1000   10020    361      3451        108
#
#                                         main_image_path
# 1304  data_main/af0f8a7b-ca71-469e-a882-f20705acf206...
# 1305  data_main/af0f8a7b-ca71-469e-a882-f20705acf206...
# 1306  data_main/af0f8a7b-ca71-469e-a882-f20705acf206...
# 1307  data_main/af0f8a7b-ca71-469e-a882-f20705acf206...
# Duplicate rows for ID 7f6e10d2-ff8d-447a-8f40-28d3c5c4c771:
#                                         id                name  \
# 1317  7f6e10d2-ff8d-447a-8f40-28d3c5c4c771  El osario de Évora
# 1318  7f6e10d2-ff8d-447a-8f40-28d3c5c4c771  El osario de Évora
# 1319  7f6e10d2-ff8d-447a-8f40-28d3c5c4c771  El osario de Évora
#
#                                        shortDescription  \
# 1317  Visita el osario de Évora, una capilla única d...
# 1318  Visita el osario de Évora, una capilla única d...
# 1319  Visita el osario de Évora, una capilla única d...
#
#                                              categories  tier  locationLon  \
# 1317  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    -7.908311
# 1318  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    -7.908311
# 1319  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    -7.908311
#
#       locationLat         tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1317    38.568979  ['Osarios']  1000   10017   3182       921        752
# 1318    38.568979   ['Momias']  1000   10009   3029      1325        747
# 1319    38.568979  ['Capilla']  1000   10010   2850      1838        490
#
#                                         main_image_path
# 1317  data_main/7f6e10d2-ff8d-447a-8f40-28d3c5c4c771...
# 1318  data_main/7f6e10d2-ff8d-447a-8f40-28d3c5c4c771...
# 1319  data_main/7f6e10d2-ff8d-447a-8f40-28d3c5c4c771...
# Duplicate rows for ID 1728c4c3-7655-497c-b4ef-76d430ee2044:
#                                         id                             name  \
# 1344  1728c4c3-7655-497c-b4ef-76d430ee2044  Gruta de las Conchas de Margate
# 1345  1728c4c3-7655-497c-b4ef-76d430ee2044  Gruta de las Conchas de Margate
# 1346  1728c4c3-7655-497c-b4ef-76d430ee2044  Gruta de las Conchas de Margate
# 1347  1728c4c3-7655-497c-b4ef-76d430ee2044  Gruta de las Conchas de Margate
#
#                                        shortDescription  \
# 1344  ¡Descubre la Gruta de las Conchas! Un enigma s...
# 1345  ¡Descubre la Gruta de las Conchas! Un enigma s...
# 1346  ¡Descubre la Gruta de las Conchas! Un enigma s...
# 1347  ¡Descubre la Gruta de las Conchas! Un enigma s...
#
#                                              categories  tier  locationLon  \
# 1344  ['Cultura', 'Arquitectura', 'Historia', 'Miste...     1     1.389906
# 1345  ['Cultura', 'Arquitectura', 'Historia', 'Miste...     1     1.389906
# 1346  ['Cultura', 'Arquitectura', 'Historia', 'Miste...     1     1.389906
# 1347  ['Cultura', 'Arquitectura', 'Historia', 'Miste...     1     1.389906
#
#       locationLat                 tags   xps  Visits  Likes  Dislikes  \
# 1344    51.387777     ['Subterráneos']  1000   10007   2881      1517
# 1345    51.387777           ['Grutas']  1000   10006    603      2689
# 1346    51.387777           ['Enigma']  1000   10019   3318      1364
# 1347    51.387777  ['Conchas marinas']  1000   10016  22327       239
#
#       Bookmarks                                    main_image_path
# 1344        619  data_main/1728c4c3-7655-497c-b4ef-76d430ee2044...
# 1345        102  data_main/1728c4c3-7655-497c-b4ef-76d430ee2044...
# 1346        606  data_main/1728c4c3-7655-497c-b4ef-76d430ee2044...
# 1347       6085  data_main/1728c4c3-7655-497c-b4ef-76d430ee2044...
# Duplicate rows for ID fb41c189-6d0a-488b-8c82-95dad97567f7:
#                                         id                  name  \
# 1385  fb41c189-6d0a-488b-8c82-95dad97567f7  Los niños de Woolpit
# 1386  fb41c189-6d0a-488b-8c82-95dad97567f7  Los niños de Woolpit
# 1387  fb41c189-6d0a-488b-8c82-95dad97567f7  Los niños de Woolpit
# 1388  fb41c189-6d0a-488b-8c82-95dad97567f7  Los niños de Woolpit
#
#                                        shortDescription  \
# 1385  ¡Descubre el misterio de Woolpit! La leyenda d...
# 1386  ¡Descubre el misterio de Woolpit! La leyenda d...
# 1387  ¡Descubre el misterio de Woolpit! La leyenda d...
# 1388  ¡Descubre el misterio de Woolpit! La leyenda d...
#
#                                categories  tier  locationLon  locationLat  \
# 1385  ['Cultura', 'Historia', 'Misterio']     1     0.887937    52.224758
# 1386  ['Cultura', 'Historia', 'Misterio']     1     0.887937    52.224758
# 1387  ['Cultura', 'Historia', 'Misterio']     1     0.887937    52.224758
# 1388  ['Cultura', 'Historia', 'Misterio']     1     0.887937    52.224758
#
#                       tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1385  ['Sucesos extraños']  1000   10007   1955      8094        205
# 1386      ['Subterráneos']  1000   10014   7916        98       2306
# 1387       ['Reptilianos']  1000   10012   2171       940        675
# 1388     ['Investigación']  1000   10018    779      2568        131
#
#                                         main_image_path
# 1385  data_main/fb41c189-6d0a-488b-8c82-95dad97567f7...
# 1386  data_main/fb41c189-6d0a-488b-8c82-95dad97567f7...
# 1387  data_main/fb41c189-6d0a-488b-8c82-95dad97567f7...
# 1388  data_main/fb41c189-6d0a-488b-8c82-95dad97567f7...
# Duplicate rows for ID bf345996-7402-47ac-abaa-cbfb19eefb0b:
#                                         id                           name  \
# 1390  bf345996-7402-47ac-abaa-cbfb19eefb0b  Monolito de Hilton of Cadboll
# 1391  bf345996-7402-47ac-abaa-cbfb19eefb0b  Monolito de Hilton of Cadboll
# 1392  bf345996-7402-47ac-abaa-cbfb19eefb0b  Monolito de Hilton of Cadboll
# 1393  bf345996-7402-47ac-abaa-cbfb19eefb0b  Monolito de Hilton of Cadboll
#
#                                        shortDescription  \
# 1390  ¡Descubre el Monolito de Hilton of Cadboll! Un...
# 1391  ¡Descubre el Monolito de Hilton of Cadboll! Un...
# 1392  ¡Descubre el Monolito de Hilton of Cadboll! Un...
# 1393  ¡Descubre el Monolito de Hilton of Cadboll! Un...
#
#                                             categories  tier  locationLon  \
# 1390  ['Cultura', 'Historia', 'Escultura', 'Misterio']     1    -3.898331
# 1391  ['Cultura', 'Historia', 'Escultura', 'Misterio']     1    -3.898331
# 1392  ['Cultura', 'Historia', 'Escultura', 'Misterio']     1    -3.898331
# 1393  ['Cultura', 'Historia', 'Escultura', 'Misterio']     1    -3.898331
#
#       locationLat             tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1390    57.761888  ['Yacimientos']  1000   10021    477      3148         87
# 1391    57.761888       ['Pictos']  1000   10014    263      3383         53
# 1392    57.761888     ['Monolito']  1000   10004    410      3297         93
# 1393    57.761888     ['Misterio']  1000   10003    191      3188        103
#
#                                         main_image_path
# 1390  data_main/bf345996-7402-47ac-abaa-cbfb19eefb0b...
# 1391  data_main/bf345996-7402-47ac-abaa-cbfb19eefb0b...
# 1392  data_main/bf345996-7402-47ac-abaa-cbfb19eefb0b...
# 1393  data_main/bf345996-7402-47ac-abaa-cbfb19eefb0b...
# Duplicate rows for ID 060c7567-ef4a-4f09-9607-a4e3c2d4ad5c:
#                                         id                name  \
# 1402  060c7567-ef4a-4f09-9607-a4e3c2d4ad5c  Londinum Mithraeum
# 1403  060c7567-ef4a-4f09-9607-a4e3c2d4ad5c  Londinum Mithraeum
# 1404  060c7567-ef4a-4f09-9607-a4e3c2d4ad5c  Londinum Mithraeum
# 1405  060c7567-ef4a-4f09-9607-a4e3c2d4ad5c  Londinum Mithraeum
# 1406  060c7567-ef4a-4f09-9607-a4e3c2d4ad5c  Londinum Mithraeum
# 1407  060c7567-ef4a-4f09-9607-a4e3c2d4ad5c  Londinum Mithraeum
#
#                                        shortDescription  \
# 1402  ¡Explora el Londinum Mithraeum! Descubre el mi...
# 1403  ¡Explora el Londinum Mithraeum! Descubre el mi...
# 1404  ¡Explora el Londinum Mithraeum! Descubre el mi...
# 1405  ¡Explora el Londinum Mithraeum! Descubre el mi...
# 1406  ¡Explora el Londinum Mithraeum! Descubre el mi...
# 1407  ¡Explora el Londinum Mithraeum! Descubre el mi...
#
#                                              categories  tier  locationLon  \
# 1402  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     -0.09063
# 1403  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     -0.09063
# 1404  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     -0.09063
# 1405  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     -0.09063
# 1406  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     -0.09063
# 1407  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     -0.09063
#
#       locationLat                       tags   xps  Visits  Likes  Dislikes  \
# 1402    51.512306            ['Yacimientos']  1000   10012    673      2761
# 1403    51.512306                ['Serapis']  1000   10007    625      2561
# 1404    51.512306  ['Religiones mistéricas']  1000   10017    695      2839
# 1405    51.512306              ['Mitraísmo']  1000   10014   2102      1221
# 1406    51.512306                  ['Mitra']  1000   10018    647      2675
# 1407    51.512306               ['Londinum']  1000   10027    858      2882
#
#       Bookmarks                                    main_image_path
# 1402        132  data_main/060c7567-ef4a-4f09-9607-a4e3c2d4ad5c...
# 1403        128  data_main/060c7567-ef4a-4f09-9607-a4e3c2d4ad5c...
# 1404        108  data_main/060c7567-ef4a-4f09-9607-a4e3c2d4ad5c...
# 1405        466  data_main/060c7567-ef4a-4f09-9607-a4e3c2d4ad5c...
# 1406        100  data_main/060c7567-ef4a-4f09-9607-a4e3c2d4ad5c...
# 1407         92  data_main/060c7567-ef4a-4f09-9607-a4e3c2d4ad5c...
# Duplicate rows for ID 31057c38-af33-46cc-95b1-341c037fec50:
#                                         id                name  \
# 1417  31057c38-af33-46cc-95b1-341c037fec50  Shrewsbury Tumulus
# 1418  31057c38-af33-46cc-95b1-341c037fec50  Shrewsbury Tumulus
# 1419  31057c38-af33-46cc-95b1-341c037fec50  Shrewsbury Tumulus
#
#                                        shortDescription  \
# 1417  ¡Explora el Shrewsbury Tumulus! Un raro túmulo...
# 1418  ¡Explora el Shrewsbury Tumulus! Un raro túmulo...
# 1419  ¡Explora el Shrewsbury Tumulus! Un raro túmulo...
#
#                                              categories  tier  locationLon  \
# 1417  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     0.070131
# 1418  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     0.070131
# 1419  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1     0.070131
#
#       locationLat                 tags   xps  Visits  Likes  Dislikes  \
# 1417    51.476366      ['Yacimientos']  1000   10014   7209      2906
# 1418    51.476366           ['Túmulo']  1000   10016   8210        79
# 1419    51.476366  ['Edad del Bronce']  1000   10018   1378      7870
#
#       Bookmarks                                    main_image_path
# 1417       1657  data_main/31057c38-af33-46cc-95b1-341c037fec50...
# 1418       2605  data_main/31057c38-af33-46cc-95b1-341c037fec50...
# 1419        298  data_main/31057c38-af33-46cc-95b1-341c037fec50...
# Duplicate rows for ID a0f3f39c-fc87-4031-900d-d4776b1f3491:
#                                         id  \
# 1420  a0f3f39c-fc87-4031-900d-d4776b1f3491
# 1421  a0f3f39c-fc87-4031-900d-d4776b1f3491
# 1422  a0f3f39c-fc87-4031-900d-d4776b1f3491
# 1423  a0f3f39c-fc87-4031-900d-d4776b1f3491
# 1424  a0f3f39c-fc87-4031-900d-d4776b1f3491
# 1425  a0f3f39c-fc87-4031-900d-d4776b1f3491
# 1426  a0f3f39c-fc87-4031-900d-d4776b1f3491
#
#                                          name  \
# 1420  Ambresbury Banks en el bosque de Epping
# 1421  Ambresbury Banks en el bosque de Epping
# 1422  Ambresbury Banks en el bosque de Epping
# 1423  Ambresbury Banks en el bosque de Epping
# 1424  Ambresbury Banks en el bosque de Epping
# 1425  Ambresbury Banks en el bosque de Epping
# 1426  Ambresbury Banks en el bosque de Epping
#
#                                        shortDescription  \
# 1420  Explora Ambresbury Banks en Epping Forest, un ...
# 1421  Explora Ambresbury Banks en Epping Forest, un ...
# 1422  Explora Ambresbury Banks en Epping Forest, un ...
# 1423  Explora Ambresbury Banks en Epping Forest, un ...
# 1424  Explora Ambresbury Banks en Epping Forest, un ...
# 1425  Explora Ambresbury Banks en Epping Forest, un ...
# 1426  Explora Ambresbury Banks en Epping Forest, un ...
#
#                                           categories  tier  locationLon  \
# 1420  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1     0.074308
# 1421  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1     0.074308
# 1422  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1     0.074308
# 1423  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1     0.074308
# 1424  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1     0.074308
# 1425  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1     0.074308
# 1426  ['Ciencia', 'Cultura', 'Historia', 'Misterio']     1     0.074308
#
#       locationLat             tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1420    51.682622     ['Pintores']  1000   10017   8653        95       2488
# 1421    51.682622   ['Naturaleza']  1000   10009    695      2856        143
# 1422    51.682622   ['Escritores']  1000   10004   8420        73       2367
# 1423    51.682622      ['Ciencia']  1000   10012    914      2569        104
# 1424    51.682622       ['Celtas']  1000   10011   3015       883        555
# 1425    51.682622       ['Bosque']  1000   10013   2860      1373        636
# 1426    51.682622  ['Arqueología']  1000   10018   8766       102       2255
#
#                                         main_image_path
# 1420  data_main/a0f3f39c-fc87-4031-900d-d4776b1f3491...
# 1421  data_main/a0f3f39c-fc87-4031-900d-d4776b1f3491...
# 1422  data_main/a0f3f39c-fc87-4031-900d-d4776b1f3491...
# 1423  data_main/a0f3f39c-fc87-4031-900d-d4776b1f3491...
# 1424  data_main/a0f3f39c-fc87-4031-900d-d4776b1f3491...
# 1425  data_main/a0f3f39c-fc87-4031-900d-d4776b1f3491...
# 1426  data_main/a0f3f39c-fc87-4031-900d-d4776b1f3491...
# Duplicate rows for ID 48057ac3-5306-422f-95fa-0ff0937124bb:
#                                         id                    name  \
# 1477  48057ac3-5306-422f-95fa-0ff0937124bb  La Quinta da Regaleira
# 1478  48057ac3-5306-422f-95fa-0ff0937124bb  La Quinta da Regaleira
# 1479  48057ac3-5306-422f-95fa-0ff0937124bb  La Quinta da Regaleira
# 1480  48057ac3-5306-422f-95fa-0ff0937124bb  La Quinta da Regaleira
# 1481  48057ac3-5306-422f-95fa-0ff0937124bb  La Quinta da Regaleira
#
#                                        shortDescription  \
# 1477  ¡Explora La Quinta da Regaleira! Un palacio de...
# 1478  ¡Explora La Quinta da Regaleira! Un palacio de...
# 1479  ¡Explora La Quinta da Regaleira! Un palacio de...
# 1480  ¡Explora La Quinta da Regaleira! Un palacio de...
# 1481  ¡Explora La Quinta da Regaleira! Un palacio de...
#
#                                              categories  tier  locationLon  \
# 1477  ['Cultura', 'Arquitectura', 'Patrimonio', 'Mis...     1     -9.39597
# 1478  ['Cultura', 'Arquitectura', 'Patrimonio', 'Mis...     1     -9.39597
# 1479  ['Cultura', 'Arquitectura', 'Patrimonio', 'Mis...     1     -9.39597
# 1480  ['Cultura', 'Arquitectura', 'Patrimonio', 'Mis...     1     -9.39597
# 1481  ['Cultura', 'Arquitectura', 'Patrimonio', 'Mis...     1     -9.39597
#
#       locationLat                       tags   xps  Visits  Likes  Dislikes  \
# 1477    38.796383                 ['UNESCO']  1000   10011  19890       282
# 1478    38.796383             ['Templarios']  1000   10005   2577      6066
# 1479    38.796383  ['Religiones mistéricas']  1000   10007   7386      3154
# 1480    38.796383              ['Masonería']  1000   10016   3444      1048
# 1481    38.796383               ['Alquimia']  1000   10021   2998      1449
#
#       Bookmarks                                    main_image_path
# 1477       5677  data_main/48057ac3-5306-422f-95fa-0ff0937124bb...
# 1478        287  data_main/48057ac3-5306-422f-95fa-0ff0937124bb...
# 1479       1769  data_main/48057ac3-5306-422f-95fa-0ff0937124bb...
# 1480        662  data_main/48057ac3-5306-422f-95fa-0ff0937124bb...
# 1481        742  data_main/48057ac3-5306-422f-95fa-0ff0937124bb...
# Duplicate rows for ID 61a339d8-d9d6-4abc-9425-455d062e3338:
#                                         id                 name  \
# 1484  61a339d8-d9d6-4abc-9425-455d062e3338  La Guarida del Lobo
# 1485  61a339d8-d9d6-4abc-9425-455d062e3338  La Guarida del Lobo
# 1486  61a339d8-d9d6-4abc-9425-455d062e3338  La Guarida del Lobo
# 1487  61a339d8-d9d6-4abc-9425-455d062e3338  La Guarida del Lobo
# 1488  61a339d8-d9d6-4abc-9425-455d062e3338  La Guarida del Lobo
# 1489  61a339d8-d9d6-4abc-9425-455d062e3338  La Guarida del Lobo
#
#                                        shortDescription  \
# 1484  Explora La Guarida del Lobo, un enigmático ref...
# 1485  Explora La Guarida del Lobo, un enigmático ref...
# 1486  Explora La Guarida del Lobo, un enigmático ref...
# 1487  Explora La Guarida del Lobo, un enigmático ref...
# 1488  Explora La Guarida del Lobo, un enigmático ref...
# 1489  Explora La Guarida del Lobo, un enigmático ref...
#
#                                              categories  tier  locationLon  \
# 1484  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.484256
# 1485  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.484256
# 1486  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.484256
# 1487  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.484256
# 1488  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.484256
# 1489  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.484256
#
#       locationLat                        tags   xps  Visits  Likes  Dislikes  \
# 1484    54.042053  ['Segunda Guerra Mundial']  1000   10010   5704      3202
# 1485    54.042053                 ['Militar']  1000   10024   3111      1515
# 1486    54.042053                  ['Hitler']  1000   10005   8505       118
# 1487    54.042053               ['Fortaleza']  1000   10015   8602       132
# 1488    54.042053                  ['Búnker']  1000   10006   8086       108
# 1489    54.042053             ['Abandonados']  1000   10018   8411        94
#
#       Bookmarks                                    main_image_path
# 1484       1842  data_main/61a339d8-d9d6-4abc-9425-455d062e3338...
# 1485        489  data_main/61a339d8-d9d6-4abc-9425-455d062e3338...
# 1486       2253  data_main/61a339d8-d9d6-4abc-9425-455d062e3338...
# 1487       2656  data_main/61a339d8-d9d6-4abc-9425-455d062e3338...
# 1488       2643  data_main/61a339d8-d9d6-4abc-9425-455d062e3338...
# 1489       2811  data_main/61a339d8-d9d6-4abc-9425-455d062e3338...
# Duplicate rows for ID 3f17de6e-21e7-4d3a-b4ec-29c0630aebb4:
#                                         id                        name  \
# 1508  3f17de6e-21e7-4d3a-b4ec-29c0630aebb4  Los monasterios de Meteora
# 1509  3f17de6e-21e7-4d3a-b4ec-29c0630aebb4  Los monasterios de Meteora
# 1510  3f17de6e-21e7-4d3a-b4ec-29c0630aebb4  Los monasterios de Meteora
# 1511  3f17de6e-21e7-4d3a-b4ec-29c0630aebb4  Los monasterios de Meteora
# 1512  3f17de6e-21e7-4d3a-b4ec-29c0630aebb4  Los monasterios de Meteora
#
#                                        shortDescription  \
# 1508  ¡Visita los monasterios de Meteora! Suspendido...
# 1509  ¡Visita los monasterios de Meteora! Suspendido...
# 1510  ¡Visita los monasterios de Meteora! Suspendido...
# 1511  ¡Visita los monasterios de Meteora! Suspendido...
# 1512  ¡Visita los monasterios de Meteora! Suspendido...
#
#                                              categories  tier  locationLon  \
# 1508  ['Arquitectura', 'Historia', 'Patrimonio', 'Mi...     1     21.63059
# 1509  ['Arquitectura', 'Historia', 'Patrimonio', 'Mi...     1     21.63059
# 1510  ['Arquitectura', 'Historia', 'Patrimonio', 'Mi...     1     21.63059
# 1511  ['Arquitectura', 'Historia', 'Patrimonio', 'Mi...     1     21.63059
# 1512  ['Arquitectura', 'Historia', 'Patrimonio', 'Mi...     1     21.63059
#
#       locationLat                  tags   xps  Visits  Likes  Dislikes  \
# 1508    39.721704       ['Monasterios']  1000   10015    930      2674
# 1509    39.721704          ['Iglesias']  1000   10010   8081       148
# 1510    39.721704  ['Iglesia Ortodoxa']  1000   10018    900      2968
# 1511    39.721704            ['Iconos']  1000   10018   6427      3511
# 1512    39.721704   ['Alejandro Magno']  1000   10024   2353       875
#
#       Bookmarks                                    main_image_path
# 1508        137  data_main/3f17de6e-21e7-4d3a-b4ec-29c0630aebb4...
# 1509       2619  data_main/3f17de6e-21e7-4d3a-b4ec-29c0630aebb4...
# 1510        119  data_main/3f17de6e-21e7-4d3a-b4ec-29c0630aebb4...
# 1511       1332  data_main/3f17de6e-21e7-4d3a-b4ec-29c0630aebb4...
# 1512        592  data_main/3f17de6e-21e7-4d3a-b4ec-29c0630aebb4...
# Duplicate rows for ID ffd48a7d-f1f7-425c-9c52-fa534cc82167:
#                                         id                 name  \
# 1513  ffd48a7d-f1f7-425c-9c52-fa534cc82167  El osario de Sedlec
# 1514  ffd48a7d-f1f7-425c-9c52-fa534cc82167  El osario de Sedlec
# 1515  ffd48a7d-f1f7-425c-9c52-fa534cc82167  El osario de Sedlec
# 1516  ffd48a7d-f1f7-425c-9c52-fa534cc82167  El osario de Sedlec
# 1517  ffd48a7d-f1f7-425c-9c52-fa534cc82167  El osario de Sedlec
#
#                                        shortDescription  \
# 1513  Visita el osario de Sedlec, un asombroso arte ...
# 1514  Visita el osario de Sedlec, un asombroso arte ...
# 1515  Visita el osario de Sedlec, un asombroso arte ...
# 1516  Visita el osario de Sedlec, un asombroso arte ...
# 1517  Visita el osario de Sedlec, un asombroso arte ...
#
#                                              categories  tier  locationLon  \
# 1513  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    15.288208
# 1514  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    15.288208
# 1515  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    15.288208
# 1516  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    15.288208
# 1517  ['Arquitectura', 'Cultura', 'Historia', 'Miste...     1    15.288208
#
#       locationLat           tags   xps  Visits  Likes  Dislikes  Bookmarks  \
# 1513    49.961723  ['Reliquias']  1000   10005   8134       120       2670
# 1514    49.961723    ['Osarios']  1000   10011   2607      1066        396
# 1515    49.961723     ['Muerte']  1000   10015   1914      1453        591
# 1516    49.961723   ['Milagros']  1000   10018   8112       104       2352
# 1517    49.961723   ['Iglesias']  1000   10009   2624       964        496
#
#                                         main_image_path
# 1513  data_main/ffd48a7d-f1f7-425c-9c52-fa534cc82167...
# 1514  data_main/ffd48a7d-f1f7-425c-9c52-fa534cc82167...
# 1515  data_main/ffd48a7d-f1f7-425c-9c52-fa534cc82167...
# 1516  data_main/ffd48a7d-f1f7-425c-9c52-fa534cc82167...
# 1517  data_main/ffd48a7d-f1f7-425c-9c52-fa534cc82167...
# Duplicate rows for ID fde6f250-9196-4ca8-8351-a9e8b15a63b6:
#                                         id                             name  \
# 1519  fde6f250-9196-4ca8-8351-a9e8b15a63b6  El Cementerio alemán de Gorlice
# 1520  fde6f250-9196-4ca8-8351-a9e8b15a63b6  El Cementerio alemán de Gorlice
# 1521  fde6f250-9196-4ca8-8351-a9e8b15a63b6  El Cementerio alemán de Gorlice
# 1522  fde6f250-9196-4ca8-8351-a9e8b15a63b6  El Cementerio alemán de Gorlice
# 1523  fde6f250-9196-4ca8-8351-a9e8b15a63b6  El Cementerio alemán de Gorlice
# 1524  fde6f250-9196-4ca8-8351-a9e8b15a63b6  El Cementerio alemán de Gorlice
#
#                                        shortDescription  \
# 1519  Visita el Cementerio Alemán de Gorlice, un emo...
# 1520  Visita el Cementerio Alemán de Gorlice, un emo...
# 1521  Visita el Cementerio Alemán de Gorlice, un emo...
# 1522  Visita el Cementerio Alemán de Gorlice, un emo...
# 1523  Visita el Cementerio Alemán de Gorlice, un emo...
# 1524  Visita el Cementerio Alemán de Gorlice, un emo...
#
#                                              categories  tier  locationLon  \
# 1519  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.159632
# 1520  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.159632
# 1521  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.159632
# 1522  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.159632
# 1523  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.159632
# 1524  ['Cultura', 'Patrimonio', 'Historia', 'Misterio']     1    21.159632
#
#       locationLat                        tags   xps  Visits  Likes  Dislikes  \
# 1519    49.654616                   ['Rusia']  1000   10013   2938      1649
# 1520    49.654616  ['Primera Guerra Mundial']  1000   10018  24233       255
# 1521    49.654616                 ['Polonia']  1000   10008    944      2719
# 1522    49.654616             ['Cementerios']  1000   10008   7878       156
# 1523    49.654616         ['Austria-Hungría']  1000   10012   8254       164
# 1524    49.654616                ['Alemania']  1000   10005    362      2879
#
#       Bookmarks                                    main_image_path
# 1519        527  data_main/fde6f250-9196-4ca8-8351-a9e8b15a63b6...
# 1520       6059  data_main/fde6f250-9196-4ca8-8351-a9e8b15a63b6...
# 1521        124  data_main/fde6f250-9196-4ca8-8351-a9e8b15a63b6...
# 1522       2751  data_main/fde6f250-9196-4ca8-8351-a9e8b15a63b6...
# 1523       2115  data_main/fde6f250-9196-4ca8-8351-a9e8b15a63b6...
# 1524         80  data_main/fde6f250-9196-4ca8-8351-a9e8b15a63b6...
# Duplicate rows for ID 651efcc9-29a8-4781-bf73-10dfa65a7d69:
#                                         id             name  \
# 1545  651efcc9-29a8-4781-bf73-10dfa65a7d69  Palacio Barolo
# 1546  651efcc9-29a8-4781-bf73-10dfa65a7d69  Palacio Barolo
# 1547  651efcc9-29a8-4781-bf73-10dfa65a7d69  Palacio Barolo
#
#                                        shortDescription   categories  tier  \
# 1545  El Palacio Barolo, inaugurado en 1923, es un e...  ['Cultura']     2
# 1546  El Palacio Barolo, inaugurado en 1923, es un e...  ['Cultura']     2
# 1547  El Palacio Barolo, inaugurado en 1923, es un e...  ['Cultura']     2
#
#       locationLon  locationLat             tags  xps  Visits  Likes  Dislikes  \
# 1545    -58.38591   -34.609677  ['Luis Barolo']  250   10022    770      3150
# 1546    -58.38591   -34.609677       ['música']  250   10017    802      2669
# 1547    -58.38591   -34.609677       ['teatro']  250   10010   6988      3715
#
#       Bookmarks                                    main_image_path
# 1545        147  data_main/651efcc9-29a8-4781-bf73-10dfa65a7d69...
# 1546         77  data_main/651efcc9-29a8-4781-bf73-10dfa65a7d69...
# 1547       1461  data_main/651efcc9-29a8-4781-bf73-10dfa65a7d69...
# Duplicate rows for ID f67f254e-da95-40ef-820c-602a2d09e979:
#                                         id                     name  \
# 1549  f67f254e-da95-40ef-820c-602a2d09e979  El Ateneo Gran Splendid
# 1550  f67f254e-da95-40ef-820c-602a2d09e979  El Ateneo Gran Splendid
# 1551  f67f254e-da95-40ef-820c-602a2d09e979  El Ateneo Gran Splendid
#
#                                        shortDescription   categories  tier  \
# 1549  El Ateneo Grand Splendid, ubicado en Buenos Ai...  ['Cultura']     2
# 1550  El Ateneo Grand Splendid, ubicado en Buenos Ai...  ['Cultura']     2
# 1551  El Ateneo Grand Splendid, ubicado en Buenos Ai...  ['Cultura']     2
#
#       locationLon  locationLat        tags  xps  Visits  Likes  Dislikes  \
# 1549   -58.394205   -34.595993  ['Ateneo']  250   10007   8095       130
# 1550   -58.394205   -34.595993  ['teatro']  250   10012    908      2915
# 1551   -58.394205   -34.595993  ['música']  250   10017   8111        73
#
#       Bookmarks                                    main_image_path
# 1549       2427  data_main/f67f254e-da95-40ef-820c-602a2d09e979...
# 1550        161  data_main/f67f254e-da95-40ef-820c-602a2d09e979...
# 1551       2497  data_main/f67f254e-da95-40ef-820c-602a2d09e979...
# Duplicate rows for ID e5427b0f-dd8c-4a31-bbe2-9c31a654a464:
#                                         id  \
# 1552  e5427b0f-dd8c-4a31-bbe2-9c31a654a464
# 1553  e5427b0f-dd8c-4a31-bbe2-9c31a654a464
#
#                                                name  \
# 1552  Museo de Arte Latinoamericano de Buenos Aires
# 1553  Museo de Arte Latinoamericano de Buenos Aires
#
#                                        shortDescription  \
# 1552  El MALBA, inaugurado en 2001, es un museo dedi...
# 1553  El MALBA, inaugurado en 2001, es un museo dedi...
#
#                                categories  tier  locationLon  locationLat  \
# 1552  ['Escultura', 'Pintura', 'Cultura']     1   -58.403419   -34.576989
# 1553  ['Escultura', 'Pintura', 'Cultura']     1   -58.403419   -34.576989
#
#                              tags  xps  Visits  Likes  Dislikes  Bookmarks  \
# 1552  ['Cultura latinoamericana']  250   10008    314      8909        137
# 1553                    ['Museo']  250   10014    261      3009        113
#
#                                         main_image_path
# 1552  data_main/e5427b0f-dd8c-4a31-bbe2-9c31a654a464...
# 1553  data_main/e5427b0f-dd8c-4a31-bbe2-9c31a654a464...
# Duplicate rows for ID d5c11570-41c3-40d2-bc1a-b3217780cd2c:
#                                         id                      name  \
# 1554  d5c11570-41c3-40d2-bc1a-b3217780cd2c  Estatua de Adolfo Alsina
# 1555  d5c11570-41c3-40d2-bc1a-b3217780cd2c  Estatua de Adolfo Alsina
#
#                                        shortDescription  \
# 1554  La estatua de Adolfo Alsina, ubicada en la Pla...
# 1555  La estatua de Adolfo Alsina, ubicada en la Pla...
#
#                        categories  tier  locationLon  locationLat  \
# 1554  ['Patrimonio', 'Escultura']     2    -58.38345   -34.597431
# 1555  ['Patrimonio', 'Escultura']     2    -58.38345   -34.597431
#
#                    tags  xps  Visits  Likes  Dislikes  Bookmarks  \
# 1554  ['Adolfo Alsina']  250   10018    104      3905         52
# 1555        ['Estatua']  250   10008    586     10285        234
#
#                                         main_image_path
# 1554  data_main/d5c11570-41c3-40d2-bc1a-b3217780cd2c...
# 1555  data_main/d5c11570-41c3-40d2-bc1a-b3217780cd2c...

# %% [markdown]
# #### Duplicados en `id`
#
# * 77 filas duplicadas (≈ 4,9 % del dataset)
# * los valores de Tags,Visits,Likes,Dislike son los únicos que cambian.
# * Para evitar *data-leakage* en el notebook de preprocesado
#   1. Fusionamos información complementaria.

# %%
non_numeric_cols = data.select_dtypes(exclude='number').columns.tolist()
print(non_numeric_cols)

for col in non_numeric_cols:
    print(f"{col} → {type(data[col][0])}")
# Out:
# ['id', 'name', 'shortDescription', 'categories', 'tags', 'main_image_path']
# id → <class 'str'>
# name → <class 'str'>
# shortDescription → <class 'str'>
# categories → <class 'str'>
# tags → <class 'str'>
# main_image_path → <class 'str'>

# %% [markdown]
# #### Resumen de columnas `object`
#
# * **`categories` / `tags`**
#   * Actualmente son strings que contienen listas.
#   * Paso pendiente en preprocesado: listas Python reales.
#   * Decidir representación posterior (one-hot, embeddings,etc)
#
# * **`shortDescription`**
#   * Texto libre calcularemos longitud y vocabulario para valorar un modelo de Tokenización.
#
# * **`main_image_path`**
#   * Ruta local a la imagen. Verificaremos que todas existan y sean accesibles antes
#
# * **`id`**
#   * resolver duplicados.

# %% [markdown]
# ### Vamos a explorar los datos  de LocationLat/Lon

# %%
# pip install plotly  (si aún no lo tienes)
import plotly.express as px

fig = px.scatter_geo(
    data,
    lat="locationLat",
    lon="locationLon",
    hover_name="name",                
    hover_data={"tier": True, "Likes": True},
    projection="natural earth",
    width=700,   
    height=550
)
fig.update_traces(marker=dict(size=5, opacity=0.7))

fig.show()

# %% [markdown]
# ### Visualización de Imagenes y paths

# %%
data.main_image_path
# Out:
# 0       data_main/4b36a3ed-3b28-4bc7-b975-1d48b586db03...
# 1       data_main/e32b3603-a94f-49df-8b31-92445a86377c...
# 2       data_main/0123a69b-13ac-4b65-a5d5-71a95560cff5...
# 3       data_main/390d7d9e-e972-451c-b5e4-f494af15e788...
# 4       data_main/023fc1bf-a1cd-4b9f-af78-48792ab1a294...
#                               ...
# 1564    data_main/a1058fc5-8b4e-43db-8758-2a4197eb69ca...
# 1565    data_main/77df8476-484e-436e-8977-f957f6b9371a...
# 1566    data_main/21c741f5-cbe7-4ae0-a69d-b5c1622056af...
# 1567    data_main/4b8b38fa-78b5-4ea8-a676-1de4e2b48caa...
# 1568    data_main/d7f45b8d-c311-4309-a85a-d91f1fcd3b2f...
# Name: main_image_path, Length: 1569, dtype: object

# %%
data.main_image_path.apply(lambda x: cv2.imread(x).shape).value_counts()
# Out:
# main_image_path
# (128, 128, 3)    1569
# Name: count, dtype: int64

# %%
plt.imshow(cv2.imread(data.main_image_path.iloc[random.randint(0, len(data))]))

# %% [markdown]
# #### Hallazgos sobre imágenes
#
# * **Integridad** → Las 1 569 rutas de `main_image_path` cargan sin error (*cv2.imread* devuelve shape válida).
# * **Resolución fija 128 × 128** → dataset ya pre-redimensionado, útil para prototipado rápido pero quizá limitado para *fine-tuning* de CNNs más profundas.

# %%
# 1. Mostrar imagen correctamente coloreada
import random, cv2, matplotlib.pyplot as plt
img = cv2.imread(data['main_image_path'].iloc[random.randint(0, len(data)-1)])
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off'); plt.title('Muestra aleatoria (RGB)')

# 2. Grid 4×4 de ejemplos
fig, axes = plt.subplots(4,4, figsize=(6,6))
for ax in axes.ravel():
    img = cv2.imread(data['main_image_path'].iloc[random.randint(0, len(data)-1)])
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    ax.axis('off')
plt.tight_layout()

# 3. Estadística básica de pixel values
import numpy as np
stats = []
for p in data['main_image_path'].sample(200, random_state=42):   # sub-sample por rapidez
    img = cv2.imread(p).astype(np.float32)/255
    stats.append(img.reshape(-1,3))
stats = np.concatenate(stats, axis=0)
print("Mean (R,G,B):", stats.mean(axis=0))
print("Std  (R,G,B):", stats.std(axis=0))
# Out:
# Mean (R,G,B): [0.4334969  0.44886053 0.45425147]
# Std  (R,G,B): [0.27410612 0.264392   0.26839465]

# %% [markdown]
# #### Estadística global de píxeles
#
# | Canal | Media | Desv. estándar |
# |-------|-------|----------------|
# | **R** | 0.433 | 0.274 |
# | **G** | 0.449 | 0.264 |
# | **B** | 0.454 | 0.268 |
#
# *Las medias se sitúan alrededor de 0.44 (en [0–1]), con una leve predominancia del azul.
# La dispersión homogénea entre canales indica buen balance de color.*
#
# > **Implicaciones para el preprocesado**
# > 1. Normalizaremos las imágenes con **`(x – mean) / std`** usando los valores anteriores.
# > 2. Añadiremos **data-augmentation** (flip, rotate, color-jitter) para contrarrestar el blur y enriquecer la variabilidad visual.
# > 3. Considerar re-escalar a **224 × 224 px** si vamos a _fine-tunear_ redes pre-entrenadas (ResNet, EfficientNet, etc.).
